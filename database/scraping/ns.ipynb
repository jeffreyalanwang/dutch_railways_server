# %%
import importlib
from pydantic import AwareDatetime, BaseModel
from typing import *
from enum import StrEnum
from zoneinfo import ZoneInfo
from datetime import datetime, timedelta, timezone, date
from pathlib import Path
from tqdm import tqdm
from itertools import chain, islice
from collections import defaultdict
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import pandas as pd
import yaml
import json
import requests
import pickle
import configparser
import nsapi

# %%
with open("../../local.properties", 'r') as file:
    config = configparser.ConfigParser()
    x = '[section]\n' + file.read()
    config.read_string(x)
    NS_PRIMARY_KEY = config.get("section", "NS_PRIMARY_KEY")
    NS_SECONDARY_KEY = config.get("section", "NS_SECONDARY_KEY")

NS_GET_HEADER = {
    'Ocp-Apim-Subscription-Key': NS_PRIMARY_KEY,
}

# https://apiportal.ns.nl/apis
NSAPI_URLS = {}
with open('./nsapi/_nsapp-stations-api.yaml') as file:
    NSAPI_URLS['STATIONS']       = yaml.full_load(file)['servers'][0]['url']
with open('./nsapi/_reisinformatie-api.yaml') as file:
    NSAPI_URLS['REISINFORMATIE'] = yaml.full_load(file)['servers'][0]['url']
with open('./nsapi/_virtual-train-API.yaml') as file:
    NSAPI_URLS['VIRTUAL_TRAIN']  = yaml.full_load(file)['servers'][0]['url']

# %%
# below not useful (only works with API at foreign station departures)
# FOR_DATE: AwareDatetime = datetime(year=2026, month=6, day=1, tzinfo=ZoneInfo('Europe/Amsterdam'))

# %% [markdown]
# ## Get train trips

# %%
# VEHICLE '/vehicle' https://apiportal.ns.nl/api-details#api=virtual-train-API&operation=getVehicles
# treinen[].ritId (string)
# treinen[].richting (float)
# treinen[].type (string)

# %%
vehicles_pkl = Path('./ns_results/raw/vehicle.pkl')
if not vehicles_pkl.exists():
    response = requests.get(NSAPI_URLS['VIRTUAL_TRAIN'] + '/vehicle', headers=NS_GET_HEADER,
        params=nsapi.virtual_train.ApiVehicleGetParameters(
            lat=52.366667, long=4.883333,
            radius=300000,
            # limit=None,
            # route=route_number,
            # features=materieel_value,
        )
    )
    print('Response:', response.json())
    obj = nsapi.virtual_train.Treinen(**response.json()['payload'])
    with open(vehicles_pkl, 'x+b') as file:
        pickle.dump(obj, file, protocol=-1)
else:
    with open(vehicles_pkl, 'rb') as file:
        obj = pickle.load(file)

# %%
_trains_raw = {
    x.ritId : x.type
    for x in obj.treinen
}
_service_types = Counter(_trains_raw.values())
TrainServiceType = StrEnum('TrainServiceType', ((x.upper(), x) for x in _service_types))

trains_type_by_id: dict[int, TrainServiceType] = {
    int(k) : TrainServiceType(v)
    for k, v in _trains_raw.items()
}

_sorted_ids = sorted(trains_type_by_id.keys())
print(_service_types)
print(f"{len(_sorted_ids)}: {min(_sorted_ids)} - {max(_sorted_ids)}")
# Out:
# Counter({'SPR': 147, 'IC': 127, 'ARR': 11})
# 285: 564 - 704371

# %% [markdown]
# ## Get trip timetables

# %%
# JOURNEY DETAILS '/v2/journey' https://apiportal.ns.nl/api-details#api=reisinformatie-api&operation=getJourneyDetail
# payload.productNumbers (string[])
# payload.plannedStock.trainParts[].stockIdentifier (string) # each trainPart has its own destination (see stop)
# payload.plannedStock.trainType (string)
# payload.stops[].stop.UICCode (string)
# payload.stops[].stop.namen.kort/lang/middel (string)
# payload.stops[].arrivals/departures.product.displayName/operatorName

# %% [markdown]
# ### For single trip

# %%
sample_train_id = 9571 #trains_type_by_id.keys().__iter__().__next__()

response = requests.get(NSAPI_URLS['REISINFORMATIE'] + '/api/v2' + '/journey', headers=NS_GET_HEADER,
    params=nsapi.reisinformatie.ApiV2JourneyGetParameters(
        train=sample_train_id, # required when not giving a journey ID
        # dateTime=FOR_DATE, # date only
        omitCrowdForecast=True,
    )
)
obj = nsapi.reisinformatie.RepresentationResponseJourney(**response.json())

class Stop(BaseModel):
    station_uic: int
    name: str
    arrives: AwareDatetime | None
    departs: AwareDatetime | None
class _TrainService0(BaseModel):
    ritnummer: int
    stops: list[Stop]
    categoryCode: str
    categoryName: str
    trainType: str | None
    trainPart_facilities: dict[int, list[str]] | None

def product_from_stops(stops: list[nsapi.reisinformatie.JourneyStop]) -> nsapi.reisinformatie.ProductInterface:
    for stop in stops:
        if stop.departures:
            return stop.departures[0].product
        if stop.arrivals:
            return stop.arrivals[0].product
    raise Exception()

def stock_from_stops(stops: list[nsapi.reisinformatie.JourneyStop]) -> nsapi.reisinformatie.Stock:
    for stop in stops:
        if stop.plannedStock:
            return stop.plannedStock
    return None

def extract_journey_data(ritnummer: int, obj: nsapi.reisinformatie.RepresentationResponseJourney):
    obj.payload.stops = [x for x in obj.payload.stops if x.status != "PASSING"]

    # assert (len(set(int(x) for x in obj.payload.productNumbers)) == 1) # not true
    assert str(ritnummer) in obj.payload.productNumbers

    for stop in obj.payload.stops:
        if len(stop.arrivals) > 1 or len(stop.departures) > 1:
            raise Exception('a')
        is_first_stop: bool = not stop.previousStopId
        is_last_stop: bool = not stop.nextStopId
        if not(is_first_stop or len(stop.arrivals) > 0):
            # raise Exception(f'Ensure requested train timetable is not for a train that has already departed. prevStopId: {stop.previousStopId}')
            pass # we cannot change this circumstance
        # assert (is_last_stop or len(stop.departures) > 0), stop.nextStopId

        for arr_or_depart in chain(stop.arrivals, stop.departures):
            assert(arr_or_depart.plannedTime.utcoffset() == timedelta(hours=2)) # 1 if DST not in effect

    return _TrainService0(
        ritnummer= ritnummer,
        stops= (Stop(
            station_uic = int(x.stop.uicCode),
            name= x.stop.name,
            arrives= x.arrivals[0].plannedTime if x.arrivals else None,
            departs= x.departures[0].plannedTime if x.departures else None,
        )   for x in obj.payload.stops),
        categoryCode= product_from_stops(obj.payload.stops).categoryCode,
        categoryName= product_from_stops(obj.payload.stops).longCategoryName,
        trainType= stock_from_stops(obj.payload.stops).trainType if stock_from_stops(obj.payload.stops) else None,
        trainPart_facilities= {
            int(y.stockIdentifier): y.facilities
            for y in stock_from_stops(obj.payload.stops).trainParts
        }   if stock_from_stops(obj.payload.stops) else None,
    )

sample_train_timetable = extract_journey_data(sample_train_id, obj)
sample_train_timetable
# Out:
# _TrainService0(ritnummer=9571, stops=[Stop(station_uic=8814001, name='Brussel-Zuid', arrives=None, departs=None), Stop(station_uic=8813003, name='Brussel-Centraal', arrives=None, departs=None), Stop(station_uic=8812005, name='Brussel-Noord', arrives=None, departs=None), Stop(station_uic=8822004, name='Mechelen', arrives=None, departs=None), Stop(station_uic=8821121, name='Antwerpen-Berchem', arrives=None, departs=None), Stop(station_uic=8821006, name='Antwerpen-Centraal', arrives=None, departs=None), Stop(station_uic=8821063, name='Antwerpen-Luchtbal', arrives=None, departs=None), Stop(station_uic=8821105, name='Noorderkempen', arrives=None, departs=None), Stop(station_uic=8400542, name='Rotterdam Lombardijen', arrives=None, departs=None), Stop(station_uic=8400534, name='Rotterdam Stadion', arrives=None, departs=None), Stop(station_uic=8400533, name='Rotterdam Zuid', arrives=None, departs=None), Stop(station_uic=8400529, name='Rotterdam Blaak', arrives=None, departs=None), Stop(station_uic=8400530, name='Rotterdam Centraal', arrives=datetime.datetime(2026, 5, 2, 20, 18, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 22, tzinfo=TzInfo(7200))), Stop(station_uic=8400531, name='Rotterdam Noord', arrives=None, departs=None), Stop(station_uic=8400507, name='Rotterdam Alexander', arrives=None, departs=None), Stop(station_uic=8400147, name='Capelle Schollevaar', arrives=None, departs=None), Stop(station_uic=8400455, name='Nieuwerkerk a/d IJssel', arrives=None, departs=None), Stop(station_uic=8400258, name='Gouda', arrives=None, departs=None), Stop(station_uic=8400257, name='Gouda Goverwelle', arrives=None, departs=None), Stop(station_uic=8400702, name='Woerden', arrives=None, departs=None), Stop(station_uic=8400133, name='Breukelen', arrives=None, departs=None), Stop(station_uic=8400047, name='Abcoude', arrives=None, departs=None), Stop(station_uic=8400231, name='Amsterdam Holendrecht', arrives=None, departs=None), Stop(station_uic=8400074, name='Amsterdam Bijlmer ArenA', arrives=None, departs=None), Stop(station_uic=8400194, name='Duivendrecht', arrives=None, departs=None), Stop(station_uic=8400057, name='Amsterdam Amstel', arrives=None, departs=None), Stop(station_uic=8400060, name='Amsterdam Muiderpoort', arrives=None, departs=None), Stop(station_uic=8400058, name='Amsterdam Centraal', arrives=datetime.datetime(2026, 5, 2, 21, 16, tzinfo=TzInfo(7200)), departs=None)], categoryCode='ECD', categoryName='Eurocity Direct', trainType=None, trainPart_facilities=None)

# %% [markdown]
# ### For all known train trips

# %%
journeys_raw_pkl = Path('./ns_results/raw/journey_details_raw.pkl')
journeys_pkl = Path('./ns_results/raw/journey_details.pkl')

def _journey_api_request(train_id: int) -> dict[str, Any]:
    response = requests.get(NSAPI_URLS['REISINFORMATIE'] + '/api/v2' + '/journey', headers=NS_GET_HEADER,
        params=nsapi.reisinformatie.ApiV2JourneyGetParameters(
            train=train_id, # required when not giving a journey ID
            omitCrowdForecast=True,
        )
    )
    return response.json()
def _get_journey_raw_obj() -> dict[str, dict[str, Any]]:
    if not journeys_raw_pkl.exists():
        train_ids = trains_type_by_id.keys()
        raw_obj = {
            train_id : _journey_api_request(train_id)
            for train_id in tqdm(train_ids)
        }
        with open(journeys_raw_pkl, 'x+b') as file:
            pickle.dump(raw_obj, file, protocol=-1)
    else:
        with open(journeys_raw_pkl, 'rb') as file:
            raw_obj = pickle.load(file)
    return raw_obj
def _get_journey_obj() -> dict[int, nsapi.reisinformatie.RepresentationResponseJourney]:
    '''May not contain all requested train_ids; some will not be found.'''
    if not journeys_pkl.exists():
        raw_obj = _get_journey_raw_obj()
        obj = dict[int, nsapi.reisinformatie.RepresentationResponseJourney]()
        for k, v in raw_obj.items():
            if (v.get('code', 200) == 404):
                continue
            obj |= {
                k : nsapi.reisinformatie.RepresentationResponseJourney(**v)
            }

        with open(journeys_pkl, 'x+b') as file:
            pickle.dump(obj, file, protocol=-1)
    else:
        with open(journeys_pkl, 'rb') as file:
            obj = pickle.load(file)
    return obj

obj = _get_journey_obj()

_trains_timetables: dict[int, _TrainService0] = {
    train_id : extract_journey_data(train_id, journey_obj)
    for train_id, journey_obj in obj.items()
}

_trains_timetables
# Out:
# {7665: _TrainService0(ritnummer=7665, stops=[Stop(station_uic=8400710, name='Wijchen', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 18, tzinfo=TzInfo(7200))), Stop(station_uic=8400475, name='Nijmegen Dukenburg', arrives=datetime.datetime(2026, 5, 2, 18, 22, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 22, tzinfo=TzInfo(7200))), Stop(station_uic=8400477, name='Nijmegen Goffert', arrives=datetime.datetime(2026, 5, 2, 18, 25, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 25, tzinfo=TzInfo(7200))), Stop(station_uic=8400470, name='Nijmegen', arrives=datetime.datetime(2026, 5, 2, 18, 29, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 32, tzinfo=TzInfo(7200))), Stop(station_uic=8400451, name='Nijmegen Lent', arrives=datetime.datetime(2026, 5, 2, 18, 35, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 35, tzinfo=TzInfo(7200))), Stop(station_uic=8400207, name='Elst', arrives=datetime.datetime(2026, 5, 2, 18, 40, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 40, tzinfo=TzInfo(7200))), Stop(station_uic=8400227, name='Arnhem Zuid', arrives=datetime.datetime(2026, 5, 2, 18, 44, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 44, tzinfo=TzInfo(7200))), Stop(station_uic=8400071, name='Arnhem Centraal', arrives=datetime.datetime(2026, 5, 2, 18, 49, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 55, tzinfo=TzInfo(7200))), Stop(station_uic=8400072, name='Arnhem Velperpoort', arrives=datetime.datetime(2026, 5, 2, 18, 57, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 57, tzinfo=TzInfo(7200))), Stop(station_uic=8400075, name='Arnhem Presikhaaf', arrives=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200))), Stop(station_uic=8400640, name='Velp', arrives=datetime.datetime(2026, 5, 2, 19, 4, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 4, tzinfo=TzInfo(7200))), Stop(station_uic=8400519, name='Rheden', arrives=datetime.datetime(2026, 5, 2, 19, 8, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 8, tzinfo=TzInfo(7200))), Stop(station_uic=8400176, name='Dieren', arrives=datetime.datetime(2026, 5, 2, 19, 13, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 14, tzinfo=TzInfo(7200))), Stop(station_uic=8400136, name='Brummen', arrives=datetime.datetime(2026, 5, 2, 19, 18, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 18, tzinfo=TzInfo(7200))), Stop(station_uic=8400744, name='Zutphen', arrives=datetime.datetime(2026, 5, 2, 19, 24, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SNG', trainPart_facilities={0: ['FIETS', 'WIFI', 'STROOM', 'TOEGANKELIJK', 'TOILET']}),
#  6668: _TrainService0(ritnummer=6668, stops=[Stop(station_uic=8400180, name='Dordrecht', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 58, tzinfo=TzInfo(7200))), Stop(station_uic=8400181, name='Dordrecht Zuid', arrives=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200))), Stop(station_uic=8400382, name='Lage Zwaluwe', arrives=datetime.datetime(2026, 5, 2, 19, 9, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200))), Stop(station_uic=8400132, name='Breda-Prinsenbeek', arrives=datetime.datetime(2026, 5, 2, 19, 17, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 17, tzinfo=TzInfo(7200))), Stop(station_uic=8400131, name='Breda', arrives=datetime.datetime(2026, 5, 2, 19, 22, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 24, tzinfo=TzInfo(7200))), Stop(station_uic=8400251, name='Gilze-Rijen', arrives=datetime.datetime(2026, 5, 2, 19, 32, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 32, tzinfo=TzInfo(7200))), Stop(station_uic=8400598, name='Tilburg Reeshof', arrives=datetime.datetime(2026, 5, 2, 19, 36, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 36, tzinfo=TzInfo(7200))), Stop(station_uic=8400594, name='Tilburg Universiteit', arrives=datetime.datetime(2026, 5, 2, 19, 40, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 40, tzinfo=TzInfo(7200))), Stop(station_uic=8400597, name='Tilburg', arrives=datetime.datetime(2026, 5, 2, 19, 43, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 44, tzinfo=TzInfo(7200))), Stop(station_uic=8400319, name="'s-Hertogenbosch", arrives=datetime.datetime(2026, 5, 2, 19, 58, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 2, tzinfo=TzInfo(7200))), Stop(station_uic=8400320, name="'s-Hertogenbosch Oost", arrives=datetime.datetime(2026, 5, 2, 20, 5, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 5, tzinfo=TzInfo(7200))), Stop(station_uic=8400524, name='Rosmalen', arrives=datetime.datetime(2026, 5, 2, 20, 9, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 9, tzinfo=TzInfo(7200))), Stop(station_uic=8400496, name='Oss West', arrives=datetime.datetime(2026, 5, 2, 20, 16, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 16, tzinfo=TzInfo(7200))), Stop(station_uic=8400495, name='Oss', arrives=datetime.datetime(2026, 5, 2, 20, 20, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 20, tzinfo=TzInfo(7200))), Stop(station_uic=8400515, name='Ravenstein', arrives=datetime.datetime(2026, 5, 2, 20, 26, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 26, tzinfo=TzInfo(7200))), Stop(station_uic=8400710, name='Wijchen', arrives=datetime.datetime(2026, 5, 2, 20, 31, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 31, tzinfo=TzInfo(7200))), Stop(station_uic=8400475, name='Nijmegen Dukenburg', arrives=datetime.datetime(2026, 5, 2, 20, 35, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 35, tzinfo=TzInfo(7200))), Stop(station_uic=8400477, name='Nijmegen Goffert', arrives=datetime.datetime(2026, 5, 2, 20, 38, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 38, tzinfo=TzInfo(7200))), Stop(station_uic=8400470, name='Nijmegen', arrives=datetime.datetime(2026, 5, 2, 20, 43, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='Flirt', trainPart_facilities={0: ['TOILET', 'STROOM', 'FIETS', 'TOEGANKELIJK', 'WIFI']}),
#  6568: _TrainService0(ritnummer=6568, stops=[Stop(station_uic=8400172, name='Deurne', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 37, tzinfo=TzInfo(7200))), Stop(station_uic=8400299, name='Helmond Brouwhuis', arrives=datetime.datetime(2026, 5, 2, 18, 42, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 42, tzinfo=TzInfo(7200))), Stop(station_uic=8400313, name='Helmond', arrives=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200))), Stop(station_uic=8400300, name="Helmond 't Hout", arrives=datetime.datetime(2026, 5, 2, 18, 49, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 49, tzinfo=TzInfo(7200))), Stop(station_uic=8400242, name='Helmond Brandevoort', arrives=datetime.datetime(2026, 5, 2, 18, 51, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 51, tzinfo=TzInfo(7200))), Stop(station_uic=8400206, name='Eindhoven Centraal', arrives=datetime.datetime(2026, 5, 2, 18, 59, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 5, tzinfo=TzInfo(7200))), Stop(station_uic=8400196, name='Eindhoven Strijp-S', arrives=datetime.datetime(2026, 5, 2, 19, 9, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 9, tzinfo=TzInfo(7200))), Stop(station_uic=8400112, name='Best', arrives=datetime.datetime(2026, 5, 2, 19, 14, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 14, tzinfo=TzInfo(7200))), Stop(station_uic=8400129, name='Boxtel', arrives=datetime.datetime(2026, 5, 2, 19, 21, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 21, tzinfo=TzInfo(7200))), Stop(station_uic=8400667, name='Vught', arrives=datetime.datetime(2026, 5, 2, 19, 28, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 28, tzinfo=TzInfo(7200))), Stop(station_uic=8400319, name="'s-Hertogenbosch", arrives=datetime.datetime(2026, 5, 2, 19, 33, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='Flirt', trainPart_facilities={0: ['TOILET', 'STROOM', 'FIETS', 'TOEGANKELIJK', 'WIFI']}),
#  6666: _TrainService0(ritnummer=6666, stops=[Stop(station_uic=8400180, name='Dordrecht', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 28, tzinfo=TzInfo(7200))), Stop(station_uic=8400181, name='Dordrecht Zuid', arrives=datetime.datetime(2026, 5, 2, 18, 31, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 31, tzinfo=TzInfo(7200))), Stop(station_uic=8400382, name='Lage Zwaluwe', arrives=datetime.datetime(2026, 5, 2, 18, 39, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 39, tzinfo=TzInfo(7200))), Stop(station_uic=8400132, name='Breda-Prinsenbeek', arrives=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200))), Stop(station_uic=8400131, name='Breda', arrives=datetime.datetime(2026, 5, 2, 18, 51, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 54, tzinfo=TzInfo(7200))), Stop(station_uic=8400251, name='Gilze-Rijen', arrives=datetime.datetime(2026, 5, 2, 19, 2, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 2, tzinfo=TzInfo(7200))), Stop(station_uic=8400598, name='Tilburg Reeshof', arrives=datetime.datetime(2026, 5, 2, 19, 6, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 6, tzinfo=TzInfo(7200))), Stop(station_uic=8400594, name='Tilburg Universiteit', arrives=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200))), Stop(station_uic=8400597, name='Tilburg', arrives=datetime.datetime(2026, 5, 2, 19, 13, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 14, tzinfo=TzInfo(7200))), Stop(station_uic=8400319, name="'s-Hertogenbosch", arrives=datetime.datetime(2026, 5, 2, 19, 30, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 32, tzinfo=TzInfo(7200))), Stop(station_uic=8400320, name="'s-Hertogenbosch Oost", arrives=datetime.datetime(2026, 5, 2, 19, 35, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 35, tzinfo=TzInfo(7200))), Stop(station_uic=8400524, name='Rosmalen', arrives=datetime.datetime(2026, 5, 2, 19, 39, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 39, tzinfo=TzInfo(7200))), Stop(station_uic=8400496, name='Oss West', arrives=datetime.datetime(2026, 5, 2, 19, 46, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 46, tzinfo=TzInfo(7200))), Stop(station_uic=8400495, name='Oss', arrives=datetime.datetime(2026, 5, 2, 19, 49, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 49, tzinfo=TzInfo(7200))), Stop(station_uic=8400515, name='Ravenstein', arrives=datetime.datetime(2026, 5, 2, 19, 55, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 55, tzinfo=TzInfo(7200))), Stop(station_uic=8400710, name='Wijchen', arrives=datetime.datetime(2026, 5, 2, 20, 1, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 1, tzinfo=TzInfo(7200))), Stop(station_uic=8400475, name='Nijmegen Dukenburg', arrives=datetime.datetime(2026, 5, 2, 20, 6, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 6, tzinfo=TzInfo(7200))), Stop(station_uic=8400477, name='Nijmegen Goffert', arrives=datetime.datetime(2026, 5, 2, 20, 9, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 9, tzinfo=TzInfo(7200))), Stop(station_uic=8400470, name='Nijmegen', arrives=datetime.datetime(2026, 5, 2, 20, 13, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='Flirt', trainPart_facilities={0: ['TOILET', 'STROOM', 'FIETS', 'TOEGANKELIJK', 'WIFI']}),
#  6463: _TrainService0(ritnummer=6463, stops=[Stop(station_uic=8400594, name='Tilburg Universiteit', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 4, tzinfo=TzInfo(7200))), Stop(station_uic=8400597, name='Tilburg', arrives=datetime.datetime(2026, 5, 2, 18, 8, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 9, tzinfo=TzInfo(7200))), Stop(station_uic=8400482, name='Oisterwijk', arrives=datetime.datetime(2026, 5, 2, 18, 15, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 15, tzinfo=TzInfo(7200))), Stop(station_uic=8400129, name='Boxtel', arrives=datetime.datetime(2026, 5, 2, 18, 22, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 23, tzinfo=TzInfo(7200))), Stop(station_uic=8400112, name='Best', arrives=datetime.datetime(2026, 5, 2, 18, 29, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 29, tzinfo=TzInfo(7200))), Stop(station_uic=8400196, name='Eindhoven Strijp-S', arrives=datetime.datetime(2026, 5, 2, 18, 35, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 35, tzinfo=TzInfo(7200))), Stop(station_uic=8400206, name='Eindhoven Centraal', arrives=datetime.datetime(2026, 5, 2, 18, 39, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 47, tzinfo=TzInfo(7200))), Stop(station_uic=8400245, name='Geldrop', arrives=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200))), Stop(station_uic=8400308, name='Heeze', arrives=datetime.datetime(2026, 5, 2, 18, 56, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 56, tzinfo=TzInfo(7200))), Stop(station_uic=8400432, name='Maarheeze', arrives=datetime.datetime(2026, 5, 2, 19, 3, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 3, tzinfo=TzInfo(7200))), Stop(station_uic=8400684, name='Weert', arrives=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='Flirt', trainPart_facilities={0: ['TOILET', 'STROOM', 'FIETS', 'TOEGANKELIJK', 'WIFI']}),
#  5663: _TrainService0(ritnummer=5663, stops=[Stop(station_uic=8400621, name='Utrecht Centraal', arrives=None, departs=datetime.datetime(2026, 5, 2, 17, 51, tzinfo=TzInfo(7200))), Stop(station_uic=8400620, name='Utrecht Overvecht', arrives=datetime.datetime(2026, 5, 2, 17, 55, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 17, 55, tzinfo=TzInfo(7200))), Stop(station_uic=8400114, name='Bilthoven', arrives=datetime.datetime(2026, 5, 2, 18, 0, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 0, tzinfo=TzInfo(7200))), Stop(station_uic=8400179, name='Den Dolder', arrives=datetime.datetime(2026, 5, 2, 18, 3, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 3, tzinfo=TzInfo(7200))), Stop(station_uic=8400055, name='Amersfoort Centraal', arrives=datetime.datetime(2026, 5, 2, 18, 10, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 12, tzinfo=TzInfo(7200))), Stop(station_uic=8400054, name='Amersfoort Schothorst', arrives=datetime.datetime(2026, 5, 2, 18, 16, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 16, tzinfo=TzInfo(7200))), Stop(station_uic=8400228, name='Amersfoort Vathorst', arrives=datetime.datetime(2026, 5, 2, 18, 19, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 19, tzinfo=TzInfo(7200))), Stop(station_uic=8400469, name='Nijkerk', arrives=datetime.datetime(2026, 5, 2, 18, 24, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 24, tzinfo=TzInfo(7200))), Stop(station_uic=8400509, name='Putten', arrives=datetime.datetime(2026, 5, 2, 18, 29, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 29, tzinfo=TzInfo(7200))), Stop(station_uic=8400216, name='Ermelo', arrives=datetime.datetime(2026, 5, 2, 18, 34, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 34, tzinfo=TzInfo(7200))), Stop(station_uic=8400294, name='Harderwijk', arrives=datetime.datetime(2026, 5, 2, 18, 38, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 38, tzinfo=TzInfo(7200))), Stop(station_uic=8400466, name='Nunspeet', arrives=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200))), Stop(station_uic=8400388, name="'t Harde", arrives=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200))), Stop(station_uic=8400690, name='Wezep', arrives=datetime.datetime(2026, 5, 2, 18, 59, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 59, tzinfo=TzInfo(7200))), Stop(station_uic=8400747, name='Zwolle', arrives=datetime.datetime(2026, 5, 2, 19, 6, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SNG', trainPart_facilities={2747: ['FIETS', 'WIFI', 'STROOM', 'TOEGANKELIJK', 'TOILET']}),
#  5161: _TrainService0(ritnummer=5161, stops=[Stop(station_uic=8400282, name='Den Haag Centraal', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 56, tzinfo=TzInfo(7200))), Stop(station_uic=8400280, name='Den Haag HS', arrives=datetime.datetime(2026, 5, 2, 18, 59, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 0, tzinfo=TzInfo(7200))), Stop(station_uic=8400279, name='Den Haag Moerwijk', arrives=datetime.datetime(2026, 5, 2, 19, 3, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 3, tzinfo=TzInfo(7200))), Stop(station_uic=8400505, name='Rijswijk', arrives=datetime.datetime(2026, 5, 2, 19, 6, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 6, tzinfo=TzInfo(7200))), Stop(station_uic=8400170, name='Delft', arrives=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200))), Stop(station_uic=8400166, name='Delft Campus', arrives=datetime.datetime(2026, 5, 2, 19, 13, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 13, tzinfo=TzInfo(7200))), Stop(station_uic=8400553, name='Schiedam Centrum', arrives=datetime.datetime(2026, 5, 2, 19, 20, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 20, tzinfo=TzInfo(7200))), Stop(station_uic=8400530, name='Rotterdam Centraal', arrives=datetime.datetime(2026, 5, 2, 19, 24, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 26, tzinfo=TzInfo(7200))), Stop(station_uic=8400529, name='Rotterdam Blaak', arrives=datetime.datetime(2026, 5, 2, 19, 29, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 29, tzinfo=TzInfo(7200))), Stop(station_uic=8400533, name='Rotterdam Zuid', arrives=datetime.datetime(2026, 5, 2, 19, 32, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 32, tzinfo=TzInfo(7200))), Stop(station_uic=8400534, name='Rotterdam Stadion', arrives=datetime.datetime(2026, 5, 2, 19, 35, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SNG', trainPart_facilities={0: ['FIETS', 'WIFI', 'STROOM', 'TOEGANKELIJK', 'TOILET']}),
#  9067: _TrainService0(ritnummer=9067, stops=[Stop(station_uic=8400394, name='Lelystad Centrum', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200))), Stop(station_uic=8400198, name='Dronten', arrives=datetime.datetime(2026, 5, 2, 19, 5, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 5, tzinfo=TzInfo(7200))), Stop(station_uic=8400360, name='Kampen Zuid', arrives=datetime.datetime(2026, 5, 2, 19, 13, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 13, tzinfo=TzInfo(7200))), Stop(station_uic=8400747, name='Zwolle', arrives=datetime.datetime(2026, 5, 2, 19, 23, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 27, tzinfo=TzInfo(7200))), Stop(station_uic=8400435, name='Meppel', arrives=datetime.datetime(2026, 5, 2, 19, 42, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 42, tzinfo=TzInfo(7200))), Stop(station_uic=8400578, name='Steenwijk', arrives=datetime.datetime(2026, 5, 2, 19, 51, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 51, tzinfo=TzInfo(7200))), Stop(station_uic=8400705, name='Wolvega', arrives=datetime.datetime(2026, 5, 2, 19, 59, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 59, tzinfo=TzInfo(7200))), Stop(station_uic=8400301, name='Heerenveen IJsstadion', arrives=None, departs=None), Stop(station_uic=8400305, name='Heerenveen', arrives=datetime.datetime(2026, 5, 2, 20, 6, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 6, tzinfo=TzInfo(7200))), Stop(station_uic=8400049, name='Akkrum', arrives=datetime.datetime(2026, 5, 2, 20, 13, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 13, tzinfo=TzInfo(7200))), Stop(station_uic=8400266, name='Grou-Jirnsum', arrives=datetime.datetime(2026, 5, 2, 20, 17, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 20, 17, tzinfo=TzInfo(7200))), Stop(station_uic=8400387, name='Leeuwarden', arrives=datetime.datetime(2026, 5, 2, 20, 27, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SNG', trainPart_facilities={0: ['FIETS', 'WIFI', 'STROOM', 'TOEGANKELIJK', 'TOILET']}),
#  4965: _TrainService0(ritnummer=4965, stops=[Stop(station_uic=8400080, name='Almere Centrum', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 21, tzinfo=TzInfo(7200))), Stop(station_uic=8400082, name='Almere Muziekwijk', arrives=datetime.datetime(2026, 5, 2, 18, 24, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 24, tzinfo=TzInfo(7200))), Stop(station_uic=8400450, name='Almere Poort', arrives=datetime.datetime(2026, 5, 2, 18, 28, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 28, tzinfo=TzInfo(7200))), Stop(station_uic=8400452, name='Naarden-Bussum', arrives=datetime.datetime(2026, 5, 2, 18, 39, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 42, tzinfo=TzInfo(7200))), Stop(station_uic=8400145, name='Bussum Zuid', arrives=None, departs=None), Stop(station_uic=8400324, name='Hilversum Media Park', arrives=None, departs=None), Stop(station_uic=8400322, name='Hilversum', arrives=datetime.datetime(2026, 5, 2, 18, 47, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 48, tzinfo=TzInfo(7200))), Stop(station_uic=8400570, name='Hilversum Sportpark', arrives=datetime.datetime(2026, 5, 2, 18, 50, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 50, tzinfo=TzInfo(7200))), Stop(station_uic=8400327, name='Hollandsche Rading', arrives=None, departs=None), Stop(station_uic=8400620, name='Utrecht Overvecht', arrives=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200))), Stop(station_uic=8400621, name='Utrecht Centraal', arrives=datetime.datetime(2026, 5, 2, 19, 5, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SNG', trainPart_facilities={0: ['FIETS', 'WIFI', 'STROOM', 'TOEGANKELIJK', 'TOILET']}),
#  7367: _TrainService0(ritnummer=7367, stops=[Stop(station_uic=8400615, name='Uitgeest', arrives=None, departs=datetime.datetime(2026, 5, 2, 17, 33, tzinfo=TzInfo(7200))), Stop(station_uic=8400368, name='Krommenie-Assendelft', arrives=datetime.datetime(2026, 5, 2, 17, 37, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 17, 37, tzinfo=TzInfo(7200))), Stop(station_uic=8400707, name='Wormerveer', arrives=datetime.datetime(2026, 5, 2, 17, 41, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 17, 41, tzinfo=TzInfo(7200))), Stop(station_uic=8400364, name='Zaandijk Zaanse Schans', arrives=datetime.datetime(2026, 5, 2, 17, 44, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 17, 44, tzinfo=TzInfo(7200))), Stop(station_uic=8400363, name='Koog aan de Zaan', arrives=datetime.datetime(2026, 5, 2, 17, 47, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 17, 47, tzinfo=TzInfo(7200))), Stop(station_uic=8400731, name='Zaandam', arrives=datetime.datetime(2026, 5, 2, 17, 50, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 17, 50, tzinfo=TzInfo(7200))), Stop(station_uic=8400059, name='Amsterdam Sloterdijk', arrives=datetime.datetime(2026, 5, 2, 17, 56, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 17, 56, tzinfo=TzInfo(7200))), Stop(station_uic=8400058, name='Amsterdam Centraal', arrives=datetime.datetime(2026, 5, 2, 18, 2, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 4, tzinfo=TzInfo(7200))), Stop(station_uic=8400060, name='Amsterdam Muiderpoort', arrives=None, departs=None), Stop(station_uic=8400057, name='Amsterdam Amstel', arrives=datetime.datetime(2026, 5, 2, 18, 11, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 11, tzinfo=TzInfo(7200))), Stop(station_uic=8400194, name='Duivendrecht', arrives=None, departs=None), Stop(station_uic=8400074, name='Amsterdam Bijlmer ArenA', arrives=datetime.datetime(2026, 5, 2, 18, 16, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 16, tzinfo=TzInfo(7200))), Stop(station_uic=8400231, name='Amsterdam Holendrecht', arrives=None, departs=None), Stop(station_uic=8400047, name='Abcoude', arrives=datetime.datetime(2026, 5, 2, 18, 20, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 20, tzinfo=TzInfo(7200))), Stop(station_uic=8400133, name='Breukelen', arrives=datetime.datetime(2026, 5, 2, 18, 27, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 28, tzinfo=TzInfo(7200))), Stop(station_uic=8400419, name='Maarssen', arrives=datetime.datetime(2026, 5, 2, 18, 33, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 33, tzinfo=TzInfo(7200))), Stop(station_uic=8400613, name='Utrecht Zuilen', arrives=datetime.datetime(2026, 5, 2, 18, 38, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 38, tzinfo=TzInfo(7200))), Stop(station_uic=8400621, name='Utrecht Centraal', arrives=datetime.datetime(2026, 5, 2, 18, 41, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 44, tzinfo=TzInfo(7200))), Stop(station_uic=8400606, name='Utrecht Vaartsche Rijn', arrives=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200))), Stop(station_uic=8400141, name='Bunnik', arrives=datetime.datetime(2026, 5, 2, 18, 51, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 51, tzinfo=TzInfo(7200))), Stop(station_uic=8400182, name='Driebergen-Zeist', arrives=datetime.datetime(2026, 5, 2, 18, 55, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 55, tzinfo=TzInfo(7200))), Stop(station_uic=8400417, name='Maarn', arrives=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200))), Stop(station_uic=8400628, name='Veenendaal West', arrives=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200))), Stop(station_uic=8400627, name='Veenendaal Centru ...
#  5159: _TrainService0(ritnummer=5159, stops=[Stop(station_uic=8400282, name='Den Haag Centraal', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 26, tzinfo=TzInfo(7200))), Stop(station_uic=8400280, name='Den Haag HS', arrives=datetime.datetime(2026, 5, 2, 18, 29, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 30, tzinfo=TzInfo(7200))), Stop(station_uic=8400279, name='Den Haag Moerwijk', arrives=datetime.datetime(2026, 5, 2, 18, 33, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 33, tzinfo=TzInfo(7200))), Stop(station_uic=8400505, name='Rijswijk', arrives=datetime.datetime(2026, 5, 2, 18, 36, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 36, tzinfo=TzInfo(7200))), Stop(station_uic=8400170, name='Delft', arrives=datetime.datetime(2026, 5, 2, 18, 40, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 40, tzinfo=TzInfo(7200))), Stop(station_uic=8400166, name='Delft Campus', arrives=datetime.datetime(2026, 5, 2, 18, 43, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 43, tzinfo=TzInfo(7200))), Stop(station_uic=8400553, name='Schiedam Centrum', arrives=datetime.datetime(2026, 5, 2, 18, 50, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 50, tzinfo=TzInfo(7200))), Stop(station_uic=8400530, name='Rotterdam Centraal', arrives=datetime.datetime(2026, 5, 2, 18, 54, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 56, tzinfo=TzInfo(7200))), Stop(station_uic=8400529, name='Rotterdam Blaak', arrives=datetime.datetime(2026, 5, 2, 18, 59, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 59, tzinfo=TzInfo(7200))), Stop(station_uic=8400533, name='Rotterdam Zuid', arrives=datetime.datetime(2026, 5, 2, 19, 2, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 2, tzinfo=TzInfo(7200))), Stop(station_uic=8400534, name='Rotterdam Stadion', arrives=datetime.datetime(2026, 5, 2, 19, 5, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SNG', trainPart_facilities={0: ['FIETS', 'WIFI', 'STROOM', 'TOEGANKELIJK', 'TOILET']}),
#  5059: _TrainService0(ritnummer=5059, stops=[Stop(station_uic=8400282, name='Den Haag Centraal', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 41, tzinfo=TzInfo(7200))), Stop(station_uic=8400280, name='Den Haag HS', arrives=datetime.datetime(2026, 5, 2, 18, 44, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200))), Stop(station_uic=8400279, name='Den Haag Moerwijk', arrives=datetime.datetime(2026, 5, 2, 18, 49, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 49, tzinfo=TzInfo(7200))), Stop(station_uic=8400505, name='Rijswijk', arrives=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200))), Stop(station_uic=8400170, name='Delft', arrives=datetime.datetime(2026, 5, 2, 18, 56, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 56, tzinfo=TzInfo(7200))), Stop(station_uic=8400166, name='Delft Campus', arrives=datetime.datetime(2026, 5, 2, 18, 59, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 59, tzinfo=TzInfo(7200))), Stop(station_uic=8400553, name='Schiedam Centrum', arrives=datetime.datetime(2026, 5, 2, 19, 5, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 5, tzinfo=TzInfo(7200))), Stop(station_uic=8400530, name='Rotterdam Centraal', arrives=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 13, tzinfo=TzInfo(7200))), Stop(station_uic=8400529, name='Rotterdam Blaak', arrives=datetime.datetime(2026, 5, 2, 19, 16, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 16, tzinfo=TzInfo(7200))), Stop(station_uic=8400533, name='Rotterdam Zuid', arrives=datetime.datetime(2026, 5, 2, 19, 19, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 19, tzinfo=TzInfo(7200))), Stop(station_uic=8400534, name='Rotterdam Stadion', arrives=datetime.datetime(2026, 5, 2, 19, 22, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SNG', trainPart_facilities={0: ['FIETS', 'WIFI', 'STROOM', 'TOEGANKELIJK', 'TOILET']}),
#  6170: _TrainService0(ritnummer=6170, stops=[Stop(station_uic=8400263, name='Groningen', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 32, tzinfo=TzInfo(7200))), Stop(station_uic=8400238, name='Groningen Europapark', arrives=datetime.datetime(2026, 5, 2, 18, 35, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 35, tzinfo=TzInfo(7200))), Stop(station_uic=8400297, name='Haren', arrives=datetime.datetime(2026, 5, 2, 18, 39, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 39, tzinfo=TzInfo(7200))), Stop(station_uic=8400073, name='Assen', arrives=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200))), Stop(station_uic=8400100, name='Beilen', arrives=datetime.datetime(2026, 5, 2, 19, 2, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 2, tzinfo=TzInfo(7200))), Stop(station_uic=8400330, name='Hoogeveen', arrives=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200))), Stop(station_uic=8400435, name='Meppel', arrives=datetime.datetime(2026, 5, 2, 19, 21, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 21, tzinfo=TzInfo(7200))), Stop(station_uic=8400747, name='Zwolle', arrives=datetime.datetime(2026, 5, 2, 19, 37, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SNG', trainPart_facilities={0: ['FIETS', 'WIFI', 'STROOM', 'TOEGANKELIJK', 'TOILET']}),
#  4366: _TrainService0(ritnummer=4366, stops=[Stop(station_uic=8400394, name='Lelystad Centrum', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 55, tzinfo=TzInfo(7200))), Stop(station_uic=8400226, name='Almere Oostvaarders', arrives=datetime.datetime(2026, 5, 2, 19, 6, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 6, tzinfo=TzInfo(7200))), Stop(station_uic=8400081, name='Almere Buiten', arrives=datetime.datetime(2026, 5, 2, 19, 9, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 9, tzinfo=TzInfo(7200))), Stop(station_uic=8400104, name='Almere Parkwijk', arrives=datetime.datetime(2026, 5, 2, 19, 13, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 13, tzinfo=TzInfo(7200))), Stop(station_uic=8400080, name='Almere Centrum', arrives=datetime.datetime(2026, 5, 2, 19, 15, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 16, tzinfo=TzInfo(7200))), Stop(station_uic=8400082, name='Almere Muziekwijk', arrives=datetime.datetime(2026, 5, 2, 19, 19, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 19, tzinfo=TzInfo(7200))), Stop(station_uic=8400450, name='Almere Poort', arrives=datetime.datetime(2026, 5, 2, 19, 23, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 23, tzinfo=TzInfo(7200))), Stop(station_uic=8400685, name='Weesp', arrives=datetime.datetime(2026, 5, 2, 19, 30, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 41, tzinfo=TzInfo(7200))), Stop(station_uic=8400163, name='Diemen Zuid', arrives=datetime.datetime(2026, 5, 2, 19, 47, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 47, tzinfo=TzInfo(7200))), Stop(station_uic=8400194, name='Duivendrecht', arrives=datetime.datetime(2026, 5, 2, 19, 50, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 52, tzinfo=TzInfo(7200))), Stop(station_uic=8400056, name='Amsterdam RAI', arrives=datetime.datetime(2026, 5, 2, 19, 56, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SLT', trainPart_facilities={0: ['FIETS', 'TOILET', 'TOEGANKELIJK']}),
#  5764: _TrainService0(ritnummer=5764, stops=[Stop(station_uic=8400621, name='Utrecht Centraal', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 41, tzinfo=TzInfo(7200))), Stop(station_uic=8400620, name='Utrecht Overvecht', arrives=datetime.datetime(2026, 5, 2, 18, 45, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 45, tzinfo=TzInfo(7200))), Stop(station_uic=8400327, name='Hollandsche Rading', arrives=datetime.datetime(2026, 5, 2, 18, 53, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 53, tzinfo=TzInfo(7200))), Stop(station_uic=8400570, name='Hilversum Sportpark', arrives=datetime.datetime(2026, 5, 2, 18, 57, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 57, tzinfo=TzInfo(7200))), Stop(station_uic=8400322, name='Hilversum', arrives=datetime.datetime(2026, 5, 2, 19, 0, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200))), Stop(station_uic=8400324, name='Hilversum Media Park', arrives=datetime.datetime(2026, 5, 2, 19, 3, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 3, tzinfo=TzInfo(7200))), Stop(station_uic=8400145, name='Bussum Zuid', arrives=datetime.datetime(2026, 5, 2, 19, 7, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 7, tzinfo=TzInfo(7200))), Stop(station_uic=8400452, name='Naarden-Bussum', arrives=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200))), Stop(station_uic=8400685, name='Weesp', arrives=datetime.datetime(2026, 5, 2, 19, 16, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 23, tzinfo=TzInfo(7200))), Stop(station_uic=8400163, name='Diemen Zuid', arrives=datetime.datetime(2026, 5, 2, 19, 30, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 30, tzinfo=TzInfo(7200))), Stop(station_uic=8400194, name='Duivendrecht', arrives=datetime.datetime(2026, 5, 2, 19, 32, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 35, tzinfo=TzInfo(7200))), Stop(station_uic=8400056, name='Amsterdam RAI', arrives=datetime.datetime(2026, 5, 2, 19, 40, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SLT', trainPart_facilities={0: ['FIETS', 'TOILET', 'TOEGANKELIJK']}),
#  5062: _TrainService0(ritnummer=5062, stops=[Stop(station_uic=8400534, name='Rotterdam Stadion', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 40, tzinfo=TzInfo(7200))), Stop(station_uic=8400533, name='Rotterdam Zuid', arrives=datetime.datetime(2026, 5, 2, 18, 42, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 42, tzinfo=TzInfo(7200))), Stop(station_uic=8400529, name='Rotterdam Blaak', arrives=datetime.datetime(2026, 5, 2, 18, 45, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 45, tzinfo=TzInfo(7200))), Stop(station_uic=8400530, name='Rotterdam Centraal', arrives=datetime.datetime(2026, 5, 2, 18, 48, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 50, tzinfo=TzInfo(7200))), Stop(station_uic=8400553, name='Schiedam Centrum', arrives=datetime.datetime(2026, 5, 2, 18, 55, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 55, tzinfo=TzInfo(7200))), Stop(station_uic=8400166, name='Delft Campus', arrives=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200))), Stop(station_uic=8400170, name='Delft', arrives=datetime.datetime(2026, 5, 2, 19, 4, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 4, tzinfo=TzInfo(7200))), Stop(station_uic=8400505, name='Rijswijk', arrives=datetime.datetime(2026, 5, 2, 19, 8, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 8, tzinfo=TzInfo(7200))), Stop(station_uic=8400279, name='Den Haag Moerwijk', arrives=datetime.datetime(2026, 5, 2, 19, 11, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 11, tzinfo=TzInfo(7200))), Stop(station_uic=8400280, name='Den Haag HS', arrives=datetime.datetime(2026, 5, 2, 19, 14, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 16, tzinfo=TzInfo(7200))), Stop(station_uic=8400282, name='Den Haag Centraal', arrives=datetime.datetime(2026, 5, 2, 19, 19, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SNG', trainPart_facilities={0: ['FIETS', 'WIFI', 'STROOM', 'TOEGANKELIJK', 'TOILET']}),
#  9065: _TrainService0(ritnummer=9065, stops=[Stop(station_uic=8400394, name='Lelystad Centrum', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 23, tzinfo=TzInfo(7200))), Stop(station_uic=8400198, name='Dronten', arrives=datetime.datetime(2026, 5, 2, 18, 36, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 36, tzinfo=TzInfo(7200))), Stop(station_uic=8400360, name='Kampen Zuid', arrives=datetime.datetime(2026, 5, 2, 18, 44, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 44, tzinfo=TzInfo(7200))), Stop(station_uic=8400747, name='Zwolle', arrives=datetime.datetime(2026, 5, 2, 18, 54, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SNG', trainPart_facilities={0: ['FIETS', 'WIFI', 'STROOM', 'TOEGANKELIJK', 'TOILET']}),
#  7362: _TrainService0(ritnummer=7362, stops=[Stop(station_uic=8400517, name='Rhenen', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 8, tzinfo=TzInfo(7200))), Stop(station_uic=8400627, name='Veenendaal Centrum', arrives=datetime.datetime(2026, 5, 2, 18, 14, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 16, tzinfo=TzInfo(7200))), Stop(station_uic=8400628, name='Veenendaal West', arrives=datetime.datetime(2026, 5, 2, 18, 19, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 19, tzinfo=TzInfo(7200))), Stop(station_uic=8400417, name='Maarn', arrives=datetime.datetime(2026, 5, 2, 18, 28, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 28, tzinfo=TzInfo(7200))), Stop(station_uic=8400182, name='Driebergen-Zeist', arrives=datetime.datetime(2026, 5, 2, 18, 34, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 34, tzinfo=TzInfo(7200))), Stop(station_uic=8400141, name='Bunnik', arrives=datetime.datetime(2026, 5, 2, 18, 38, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 38, tzinfo=TzInfo(7200))), Stop(station_uic=8400606, name='Utrecht Vaartsche Rijn', arrives=datetime.datetime(2026, 5, 2, 18, 43, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 43, tzinfo=TzInfo(7200))), Stop(station_uic=8400621, name='Utrecht Centraal', arrives=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 49, tzinfo=TzInfo(7200))), Stop(station_uic=8400613, name='Utrecht Zuilen', arrives=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200))), Stop(station_uic=8400419, name='Maarssen', arrives=datetime.datetime(2026, 5, 2, 18, 57, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 57, tzinfo=TzInfo(7200))), Stop(station_uic=8400133, name='Breukelen', arrives=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SNG', trainPart_facilities={0: ['FIETS', 'WIFI', 'STROOM', 'TOEGANKELIJK', 'TOILET']}),
#  7369: _TrainService0(ritnummer=7369, stops=[Stop(station_uic=8400133, name='Breukelen', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 58, tzinfo=TzInfo(7200))), Stop(station_uic=8400419, name='Maarssen', arrives=datetime.datetime(2026, 5, 2, 19, 3, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 3, tzinfo=TzInfo(7200))), Stop(station_uic=8400613, name='Utrecht Zuilen', arrives=datetime.datetime(2026, 5, 2, 19, 8, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 8, tzinfo=TzInfo(7200))), Stop(station_uic=8400621, name='Utrecht Centraal', arrives=datetime.datetime(2026, 5, 2, 19, 11, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 14, tzinfo=TzInfo(7200))), Stop(station_uic=8400606, name='Utrecht Vaartsche Rijn', arrives=datetime.datetime(2026, 5, 2, 19, 16, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 16, tzinfo=TzInfo(7200))), Stop(station_uic=8400141, name='Bunnik', arrives=datetime.datetime(2026, 5, 2, 19, 21, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 21, tzinfo=TzInfo(7200))), Stop(station_uic=8400182, name='Driebergen-Zeist', arrives=datetime.datetime(2026, 5, 2, 19, 25, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 25, tzinfo=TzInfo(7200))), Stop(station_uic=8400417, name='Maarn', arrives=datetime.datetime(2026, 5, 2, 19, 31, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 31, tzinfo=TzInfo(7200))), Stop(station_uic=8400628, name='Veenendaal West', arrives=datetime.datetime(2026, 5, 2, 19, 40, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 40, tzinfo=TzInfo(7200))), Stop(station_uic=8400627, name='Veenendaal Centrum', arrives=datetime.datetime(2026, 5, 2, 19, 43, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 45, tzinfo=TzInfo(7200))), Stop(station_uic=8400517, name='Rhenen', arrives=datetime.datetime(2026, 5, 2, 19, 51, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SNG', trainPart_facilities={0: ['FIETS', 'WIFI', 'STROOM', 'TOEGANKELIJK', 'TOILET']}),
#  5160: _TrainService0(ritnummer=5160, stops=[Stop(station_uic=8400534, name='Rotterdam Stadion', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 25, tzinfo=TzInfo(7200))), Stop(station_uic=8400533, name='Rotterdam Zuid', arrives=datetime.datetime(2026, 5, 2, 18, 27, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 27, tzinfo=TzInfo(7200))), Stop(station_uic=8400529, name='Rotterdam Blaak', arrives=datetime.datetime(2026, 5, 2, 18, 30, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 30, tzinfo=TzInfo(7200))), Stop(station_uic=8400530, name='Rotterdam Centraal', arrives=datetime.datetime(2026, 5, 2, 18, 33, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 35, tzinfo=TzInfo(7200))), Stop(station_uic=8400553, name='Schiedam Centrum', arrives=datetime.datetime(2026, 5, 2, 18, 39, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 39, tzinfo=TzInfo(7200))), Stop(station_uic=8400166, name='Delft Campus', arrives=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200))), Stop(station_uic=8400170, name='Delft', arrives=datetime.datetime(2026, 5, 2, 18, 48, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 48, tzinfo=TzInfo(7200))), Stop(station_uic=8400505, name='Rijswijk', arrives=datetime.datetime(2026, 5, 2, 18, 53, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 53, tzinfo=TzInfo(7200))), Stop(station_uic=8400279, name='Den Haag Moerwijk', arrives=datetime.datetime(2026, 5, 2, 18, 56, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 56, tzinfo=TzInfo(7200))), Stop(station_uic=8400280, name='Den Haag HS', arrives=datetime.datetime(2026, 5, 2, 18, 59, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200))), Stop(station_uic=8400282, name='Den Haag Centraal', arrives=datetime.datetime(2026, 5, 2, 19, 4, tzinfo=TzInfo(7200)), departs=None)], categoryCode='SPR', categoryName='Sprinter', trainType='SNG', trainPart_facilities={0: ['FIETS', 'WIFI', 'STROOM', 'TOEGANKELIJK', 'TOILET']}),
# ...
#  37861: _TrainService0(ritnummer=37861, stops=[Stop(station_uic=8400636, name='Veendam', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 2, tzinfo=TzInfo(7200))), Stop(station_uic=8400742, name='Zuidbroek', arrives=datetime.datetime(2026, 5, 2, 18, 8, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 8, tzinfo=TzInfo(7200))), Stop(station_uic=8400331, name='Hoogezand-Sappemeer', arrives=datetime.datetime(2026, 5, 2, 18, 13, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 13, tzinfo=TzInfo(7200))), Stop(station_uic=8400430, name='Martenshoek', arrives=datetime.datetime(2026, 5, 2, 18, 16, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 16, tzinfo=TzInfo(7200))), Stop(station_uic=8400369, name='Kropswolde', arrives=datetime.datetime(2026, 5, 2, 18, 19, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 19, tzinfo=TzInfo(7200))), Stop(station_uic=8400238, name='Groningen Europapark', arrives=datetime.datetime(2026, 5, 2, 18, 27, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 27, tzinfo=TzInfo(7200))), Stop(station_uic=8400263, name='Groningen', arrives=datetime.datetime(2026, 5, 2, 18, 30, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 34, tzinfo=TzInfo(7200))), Stop(station_uic=8400264, name='Groningen Noord', arrives=datetime.datetime(2026, 5, 2, 18, 38, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 40, tzinfo=TzInfo(7200))), Stop(station_uic=8400547, name='Sauwerd', arrives=datetime.datetime(2026, 5, 2, 18, 45, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 45, tzinfo=TzInfo(7200))), Stop(station_uic=8400094, name='Bedum', arrives=datetime.datetime(2026, 5, 2, 18, 50, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 50, tzinfo=TzInfo(7200))), Stop(station_uic=8400576, name='Stedum', arrives=datetime.datetime(2026, 5, 2, 18, 56, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 56, tzinfo=TzInfo(7200))), Stop(station_uic=8400403, name='Loppersum', arrives=datetime.datetime(2026, 5, 2, 19, 0, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 0, tzinfo=TzInfo(7200))), Stop(station_uic=8400067, name='Appingedam', arrives=datetime.datetime(2026, 5, 2, 19, 6, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 7, tzinfo=TzInfo(7200))), Stop(station_uic=8400175, name='Delfzijl West', arrives=datetime.datetime(2026, 5, 2, 19, 11, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 11, tzinfo=TzInfo(7200))), Stop(station_uic=8400171, name='Delfzijl', arrives=datetime.datetime(2026, 5, 2, 19, 13, tzinfo=TzInfo(7200)), departs=None)], categoryCode='ST', categoryName='Stoptrein', trainType='GTW', trainPart_facilities={0: ['TOILET', 'STROOM', 'TOEGANKELIJK']}),
#  8061: _TrainService0(ritnummer=8061, stops=[Stop(station_uic=8400747, name='Zwolle', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200))), Stop(station_uic=8400167, name='Dalfsen', arrives=datetime.datetime(2026, 5, 2, 18, 59, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 0, tzinfo=TzInfo(7200))), Stop(station_uic=8400487, name='Ommen', arrives=datetime.datetime(2026, 5, 2, 19, 6, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 7, tzinfo=TzInfo(7200))), Stop(station_uic=8400428, name='Mariënberg', arrives=datetime.datetime(2026, 5, 2, 19, 14, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 14, tzinfo=TzInfo(7200))), Stop(station_uic=8400293, name='Hardenberg', arrives=datetime.datetime(2026, 5, 2, 19, 19, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 19, tzinfo=TzInfo(7200))), Stop(station_uic=8400259, name='Gramsbergen', arrives=datetime.datetime(2026, 5, 2, 19, 24, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 24, tzinfo=TzInfo(7200))), Stop(station_uic=8400153, name='Coevorden', arrives=datetime.datetime(2026, 5, 2, 19, 30, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 32, tzinfo=TzInfo(7200))), Stop(station_uic=8400161, name='Dalen', arrives=datetime.datetime(2026, 5, 2, 19, 35, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 35, tzinfo=TzInfo(7200))), Stop(station_uic=8400454, name='Nieuw Amsterdam', arrives=datetime.datetime(2026, 5, 2, 19, 40, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 41, tzinfo=TzInfo(7200))), Stop(station_uic=8400407, name='Emmen Zuid', arrives=datetime.datetime(2026, 5, 2, 19, 44, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 45, tzinfo=TzInfo(7200))), Stop(station_uic=8400208, name='Emmen', arrives=datetime.datetime(2026, 5, 2, 19, 50, tzinfo=TzInfo(7200)), departs=None)], categoryCode='ST', categoryName='Stoptrein', trainType='GTW', trainPart_facilities={0: ['TOILET', 'STROOM', 'TOEGANKELIJK']}),
#  30860: _TrainService0(ritnummer=30860, stops=[Stop(station_uic=8400698, name='Winterswijk', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 50, tzinfo=TzInfo(7200))), Stop(station_uic=8400700, name='Winterswijk West', arrives=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200))), Stop(station_uic=8400395, name='Lichtenvoorde-Groenlo', arrives=datetime.datetime(2026, 5, 2, 18, 59, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 0, tzinfo=TzInfo(7200))), Stop(station_uic=8400537, name='Ruurlo', arrives=datetime.datetime(2026, 5, 2, 19, 8, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 8, tzinfo=TzInfo(7200))), Stop(station_uic=8400661, name='Vorden', arrives=datetime.datetime(2026, 5, 2, 19, 14, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 15, tzinfo=TzInfo(7200))), Stop(station_uic=8400744, name='Zutphen', arrives=datetime.datetime(2026, 5, 2, 19, 23, tzinfo=TzInfo(7200)), departs=None)], categoryCode='ST', categoryName='Stoptrein', trainType='GTW', trainPart_facilities={0: ['STROOM', 'TOEGANKELIJK']}),
#  3859: _TrainService0(ritnummer=3859, stops=[Stop(station_uic=8400747, name='Zwolle', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 22, tzinfo=TzInfo(7200))), Stop(station_uic=8400167, name='Dalfsen', arrives=datetime.datetime(2026, 5, 2, 18, 29, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 30, tzinfo=TzInfo(7200))), Stop(station_uic=8400487, name='Ommen', arrives=datetime.datetime(2026, 5, 2, 18, 36, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 37, tzinfo=TzInfo(7200))), Stop(station_uic=8400428, name='Mariënberg', arrives=datetime.datetime(2026, 5, 2, 18, 44, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 44, tzinfo=TzInfo(7200))), Stop(station_uic=8400293, name='Hardenberg', arrives=datetime.datetime(2026, 5, 2, 18, 49, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 49, tzinfo=TzInfo(7200))), Stop(station_uic=8400259, name='Gramsbergen', arrives=None, departs=None), Stop(station_uic=8400153, name='Coevorden', arrives=datetime.datetime(2026, 5, 2, 18, 58, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 0, tzinfo=TzInfo(7200))), Stop(station_uic=8400161, name='Dalen', arrives=None, departs=None), Stop(station_uic=8400454, name='Nieuw Amsterdam', arrives=datetime.datetime(2026, 5, 2, 19, 6, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 7, tzinfo=TzInfo(7200))), Stop(station_uic=8400407, name='Emmen Zuid', arrives=datetime.datetime(2026, 5, 2, 19, 11, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 11, tzinfo=TzInfo(7200))), Stop(station_uic=8400208, name='Emmen', arrives=datetime.datetime(2026, 5, 2, 19, 15, tzinfo=TzInfo(7200)), departs=None)], categoryCode='S', categoryName='Sneltrein', trainType='GTW', trainPart_facilities={0: ['TOILET', 'STROOM', 'TOEGANKELIJK']}),
#  32466: _TrainService0(ritnummer=32466, stops=[Stop(station_uic=8400426, name='Maastricht Randwyck', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 35, tzinfo=TzInfo(7200))), Stop(station_uic=8400424, name='Maastricht', arrives=datetime.datetime(2026, 5, 2, 18, 38, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 41, tzinfo=TzInfo(7200))), Stop(station_uic=8400140, name='Bunde', arrives=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 46, tzinfo=TzInfo(7200))), Stop(station_uic=8400096, name='Beek-Elsloo', arrives=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200))), Stop(station_uic=8400248, name='Geleen-Lutterade', arrives=datetime.datetime(2026, 5, 2, 18, 55, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 57, tzinfo=TzInfo(7200))), Stop(station_uic=8400564, name='Sittard', arrives=datetime.datetime(2026, 5, 2, 19, 1, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 8, tzinfo=TzInfo(7200))), Stop(station_uic=8400582, name='Susteren', arrives=datetime.datetime(2026, 5, 2, 19, 13, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 13, tzinfo=TzInfo(7200))), Stop(station_uic=8400195, name='Echt', arrives=datetime.datetime(2026, 5, 2, 19, 17, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 17, tzinfo=TzInfo(7200))), Stop(station_uic=8400523, name='Roermond', arrives=datetime.datetime(2026, 5, 2, 19, 26, tzinfo=TzInfo(7200)), departs=None)], categoryCode='ST', categoryName='Stoptrein', trainType='Flirt', trainPart_facilities={0: ['TOILET', 'STROOM', 'FIETS', 'TOEGANKELIJK', 'WIFI']}),
#  32464: _TrainService0(ritnummer=32464, stops=[Stop(station_uic=8400426, name='Maastricht Randwyck', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 5, tzinfo=TzInfo(7200))), Stop(station_uic=8400424, name='Maastricht', arrives=datetime.datetime(2026, 5, 2, 18, 8, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 11, tzinfo=TzInfo(7200))), Stop(station_uic=8400140, name='Bunde', arrives=datetime.datetime(2026, 5, 2, 18, 16, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 16, tzinfo=TzInfo(7200))), Stop(station_uic=8400096, name='Beek-Elsloo', arrives=datetime.datetime(2026, 5, 2, 18, 22, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 22, tzinfo=TzInfo(7200))), Stop(station_uic=8400248, name='Geleen-Lutterade', arrives=datetime.datetime(2026, 5, 2, 18, 25, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 27, tzinfo=TzInfo(7200))), Stop(station_uic=8400564, name='Sittard', arrives=datetime.datetime(2026, 5, 2, 18, 31, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 38, tzinfo=TzInfo(7200))), Stop(station_uic=8400582, name='Susteren', arrives=datetime.datetime(2026, 5, 2, 18, 43, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 43, tzinfo=TzInfo(7200))), Stop(station_uic=8400195, name='Echt', arrives=datetime.datetime(2026, 5, 2, 18, 47, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 47, tzinfo=TzInfo(7200))), Stop(station_uic=8400523, name='Roermond', arrives=datetime.datetime(2026, 5, 2, 18, 56, tzinfo=TzInfo(7200)), departs=None)], categoryCode='ST', categoryName='Stoptrein', trainType='Flirt', trainPart_facilities={0: ['TOILET', 'STROOM', 'FIETS', 'TOEGANKELIJK', 'WIFI']}),
#  31154: _TrainService0(ritnummer=31154, stops=[Stop(station_uic=8400071, name='Arnhem Centraal', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 38, tzinfo=TzInfo(7200))), Stop(station_uic=8400227, name='Arnhem Zuid', arrives=None, departs=None), Stop(station_uic=8400207, name='Elst', arrives=datetime.datetime(2026, 5, 2, 18, 44, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 45, tzinfo=TzInfo(7200))), Stop(station_uic=8400734, name='Zetten-Andelst', arrives=datetime.datetime(2026, 5, 2, 18, 54, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 54, tzinfo=TzInfo(7200))), Stop(station_uic=8400315, name='Hemmen-Dodewaard', arrives=datetime.datetime(2026, 5, 2, 18, 57, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 57, tzinfo=TzInfo(7200))), Stop(station_uic=8400494, name='Opheusden', arrives=datetime.datetime(2026, 5, 2, 19, 0, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 0, tzinfo=TzInfo(7200))), Stop(station_uic=8400359, name='Kesteren', arrives=datetime.datetime(2026, 5, 2, 19, 4, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 4, tzinfo=TzInfo(7200))), Stop(station_uic=8400596, name='Tiel', arrives=datetime.datetime(2026, 5, 2, 19, 13, tzinfo=TzInfo(7200)), departs=None)], categoryCode='ST', categoryName='Stoptrein', trainType='GTW', trainPart_facilities={0: ['STROOM', 'TOEGANKELIJK']}),
#  30958: _TrainService0(ritnummer=30958, stops=[Stop(station_uic=8400698, name='Winterswijk', arrives=None, departs=datetime.datetime(2026, 5, 2, 18, 20, tzinfo=TzInfo(7200))), Stop(station_uic=8400045, name='Aalten', arrives=datetime.datetime(2026, 5, 2, 18, 29, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 30, tzinfo=TzInfo(7200))), Stop(station_uic=8400635, name='Varsseveld', arrives=datetime.datetime(2026, 5, 2, 18, 37, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 37, tzinfo=TzInfo(7200))), Stop(station_uic=8400592, name='Terborg', arrives=datetime.datetime(2026, 5, 2, 18, 44, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 45, tzinfo=TzInfo(7200))), Stop(station_uic=8400241, name='Gaanderen', arrives=datetime.datetime(2026, 5, 2, 18, 47, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 47, tzinfo=TzInfo(7200))), Stop(station_uic=8400177, name='Doetinchem', arrives=datetime.datetime(2026, 5, 2, 18, 52, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 53, tzinfo=TzInfo(7200))), Stop(station_uic=8400184, name='Doetinchem De Huet', arrives=datetime.datetime(2026, 5, 2, 18, 56, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 18, 56, tzinfo=TzInfo(7200))), Stop(station_uic=8400686, name='Wehl', arrives=datetime.datetime(2026, 5, 2, 18, 59, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 0, tzinfo=TzInfo(7200))), Stop(station_uic=8400174, name='Didam', arrives=datetime.datetime(2026, 5, 2, 19, 5, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 5, tzinfo=TzInfo(7200))), Stop(station_uic=8400735, name='Zevenaar', arrives=datetime.datetime(2026, 5, 2, 19, 9, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 10, tzinfo=TzInfo(7200))), Stop(station_uic=8400193, name='Duiven', arrives=datetime.datetime(2026, 5, 2, 19, 14, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 14, tzinfo=TzInfo(7200))), Stop(station_uic=8400688, name='Westervoort', arrives=datetime.datetime(2026, 5, 2, 19, 18, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 18, tzinfo=TzInfo(7200))), Stop(station_uic=8400072, name='Arnhem Velperpoort', arrives=datetime.datetime(2026, 5, 2, 19, 22, tzinfo=TzInfo(7200)), departs=datetime.datetime(2026, 5, 2, 19, 22, tzinfo=TzInfo(7200))), Stop(station_uic=8400071, name='Arnhem Centraal', arrives=datetime.datetime(2026, 5, 2, 19, 25, tzinfo=TzInfo(7200)), departs=None)], categoryCode='ST', categoryName='Stoptrein', trainType='GTW', trainPart_facilities={0: ['STROOM', 'TOEGANKELIJK']})}

# %% [markdown]
# #### Create enums

# %%
_category_codes = Counter(x.categoryCode for x in _trains_timetables.values())
CategoryCode = StrEnum('CategoryCode', ((x.upper(), x) for x in _category_codes))
print(_category_codes)

_category_names = Counter(x.categoryName for x in _trains_timetables.values())
CategoryName = StrEnum('CategoryName', ((x.upper(), x) for x in _category_names))
print(_category_names)

_train_types = Counter(x.trainType for x in _trains_timetables.values() if x.trainType)
TrainType = StrEnum('TrainType', ((x.upper(), x) for x in _train_types))
print(_train_types)

_facilities = Counter(
    z
    for x in _trains_timetables.values()
    if x.trainPart_facilities
    for y in x.trainPart_facilities.values()
    for z in y
)
Facility = StrEnum('Facility', ((x.upper(), x) for x in _facilities))
print(_facilities)
# Out:
# Counter({'SPR': 117, 'IC': 100, 'ST': 8, 'ECD': 6, 'S': 1})
# Counter({'Sprinter': 117, 'Intercity': 100, 'Stoptrein': 8, 'Eurocity Direct': 6, 'Sneltrein': 1})
# Counter({'VIRM': 67, 'SNG': 51, 'SLT': 44, 'Flirt': 24, 'DDZ': 16, 'ICM': 11, 'ICNG': 9, 'GTW': 7})
# Counter({'TOILET': 241, 'FIETS': 238, 'WIFI': 190, 'STROOM': 149, 'TOEGANKELIJK': 142, 'STILTE': 114})

# %% [markdown]
# #### Apply enums

# %%
class TrainService(BaseModel):
    ritnummer: int
    stops: list[Stop]
    categoryCode: CategoryCode
    categoryName: CategoryName
    trainType: TrainType | None
class StockFacility(BaseModel):
    trainType: TrainType
    facilities: list[Facility]

train_timetables = {
    k : TrainService(
        ritnummer= v.ritnummer,
        stops= v.stops,
        categoryCode= CategoryCode(v.categoryCode),
        categoryName= CategoryName(v.categoryName),
        trainType= TrainType(v.trainType) if v.trainType else None,
    )
    for k, v in _trains_timetables.items()
}

_facilities_by_trainType: defaultdict[TrainType, Counter[Facility]] = defaultdict(lambda: Counter[Facility]())
for v in _trains_timetables.values():
    if not(v.trainType) and not(v.trainPart_facilities):
        continue
    _facilities_by_trainType[v.trainType].update(
        Facility(x)
        for facilities in v.trainPart_facilities.values()
        for x in facilities
    )
print(json.dumps(_facilities_by_trainType, indent=4))

facilities_by_trainType: dict[TrainType, list[Facility]] = {
    k : list[Facility](v.keys())
    for k, v in _facilities_by_trainType.items()
}
# Out:
# {
#     "SNG": {
#         "FIETS": 51,
#         "WIFI": 51,
#         "STROOM": 51,
#         "TOEGANKELIJK": 51,
#         "TOILET": 51
#     },
#     "Flirt": {
#         "TOILET": 25,
#         "STROOM": 25,
#         "FIETS": 25,
#         "TOEGANKELIJK": 25,
#         "WIFI": 25
#     },
#     "SLT": {
#         "FIETS": 48,
#         "TOILET": 48,
#         "TOEGANKELIJK": 48
#     },
#     "ICNG": {
#         "WIFI": 11,
#         "TOILET": 11,
#         "STILTE": 11,
#         "STROOM": 11,
#         "FIETS": 11,
#         "TOEGANKELIJK": 11
#     },
#     "ICM": {
#         "WIFI": 13,
#         "TOILET": 13,
#         "STILTE": 13,
#         "STROOM": 13,
#         "FIETS": 13
#     },
#     "VIRM": {
#         "WIFI": 74,
#         "TOILET": 74,
#         "STILTE": 74,
#         "FIETS": 74,
#         "STROOM": 26
#     },
#     "DDZ": {
#         "WIFI": 16,
#         "TOILET": 16,
#         "STILTE": 16,
#         "STROOM": 16,
#         "FIETS": 16
#     },
#     "GTW": {
#         "STROOM": 7,
#         "TOEGANKELIJK": 7,
#         "TOILET": 3
#     }
# }

# %% [markdown]
# ## Get train stations

# %%
# STATIONS '/v3' https://apiportal.ns.nl/api-details#api=nsapp-stations-api&operation=getStationsV3
# payload.id.uicCode
# payload.id.code # eg UT for Utrecht Centraal
# payload.stationType (enum)
# payload.names.long/medium/short/festive/synonyms[]
# payload.location.lat/lng (number)

# %%
stations_pkl = Path('ns_results/raw/stations.pkl')
if not stations_pkl.exists():
    response = requests.get(NSAPI_URLS['STATIONS'] + '/v3', headers=NS_GET_HEADER,
        params=nsapi.nsapp_stations.V3GetParameters(
            countryCodes=['NL'],
            limit=None # irrelevant when not providing str `q`
        )
    )
    obj = nsapi.nsapp_stations.StationsV3Response(**response.json())
    with open(stations_pkl, 'x+b') as file:
        pickle.dump(obj, file, protocol=-1)
else:
    with open(stations_pkl, 'rb') as file:
        obj = pickle.load(file)

# %%
StationInfo = NamedTuple('StationInfo', (
    ('name', str),
    ('lat', float),
    ('lng', float),
))

stations_by_uicCode: dict[int, StationInfo] = {
    int(x.id.uicCode) : StationInfo(
        name=x.names.long,
        lat=x.location.lat,
        lng=x.location.lng,
    )
    for x in obj.payload
}

_uics = sorted(stations_by_uicCode.keys())
_names_len = sorted(
    (x.name for x in stations_by_uicCode.values()),
    key=len
)
_names_words = sorted(
    (x.name for x in stations_by_uicCode.values()),
    key=lambda s: len(s.split())
)
print(_uics[:1] + ['...'] + _uics[-1:])
print('========')
print(_names_len[:3] + ['...'] + _names_len[-3:])
print('========')
print(_names_words[:3] + ['...'] + _names_words[-3:])
# Out:
# [8400045, '...', 8400752]
# ========
# ['Oss', 'Olst', 'Elst', '...', 'Bovenkarspel-Grootebroek', 'Lansingerland-Zoetermeer', 'Leeuwarden Camminghaburen']
# ========
# ["'s-Hertogenbosch", 'Alkmaar', 'Almelo', '...', 'Zandvoort aan Zee', 'Koog aan de Zaan', 'Den Haag Laan v NOI']

# %% [markdown]
# ## Export for SQL

# %%
reveal_type(trains_type_by_id)
reveal_type(train_timetables)
reveal_type(facilities_by_trainType)
reveal_type(stations_by_uicCode)

# %%
geolocator = Nominatim(user_agent="ns_train_stations_scraper")
geolocator_rate_limited = RateLimiter(geolocator.reverse, min_delay_seconds=2)

# %%
addresses_pkl = Path('./ns_results/raw/addresses.pkl')
if not addresses_pkl.exists():
    sql_stations = pd.DataFrame({
        'uic': uic,
        'name': v.name,
        'lat': v.lat,
        'lng': v.lng,
        'address': geolocator_rate_limited(f"{v.lat}, {v.lng}").address,
    }   for uic, v in stations_by_uicCode.items())
    with open(addresses_pkl, 'xb') as file:
        pickle.dump(sql_stations, file, protocol=-1)
else:
    with open(addresses_pkl, 'r+b') as file:
        sql_stations = pickle.load(file)

# %%
sql_trainsetamenities = pd.DataFrame([
    {
        'trainset': trainset,
        'amenity': amenity,
    }
    for trainset, facilities in facilities_by_trainType.items()
    for amenity in facilities
])
sql_trainsetamenities
# Out:
#    trainset       amenity
# 0       SNG         FIETS
# 1       SNG          WIFI
# 2       SNG        STROOM
# 3       SNG  TOEGANKELIJK
# 4       SNG        TOILET
# 5     Flirt        TOILET
# 6     Flirt        STROOM
# 7     Flirt         FIETS
# 8     Flirt  TOEGANKELIJK
# 9     Flirt          WIFI
# 10      SLT         FIETS
# 11      SLT        TOILET
# 12      SLT  TOEGANKELIJK
# 13     ICNG          WIFI
# 14     ICNG        TOILET
# 15     ICNG        STILTE
# 16     ICNG        STROOM
# 17     ICNG         FIETS
# 18     ICNG  TOEGANKELIJK
# 19      ICM          WIFI
# 20      ICM        TOILET
# 21      ICM        STILTE
# 22      ICM        STROOM
# 23      ICM         FIETS
# 24     VIRM          WIFI
# 25     VIRM        TOILET
# 26     VIRM        STILTE
# 27     VIRM         FIETS
# 28     VIRM        STROOM
# 29      DDZ          WIFI
# 30      DDZ        TOILET
# 31      DDZ        STILTE
# 32      DDZ        STROOM
# 33      DDZ         FIETS
# 34      GTW        STROOM
# 35      GTW  TOEGANKELIJK
# 36      GTW        TOILET

# %%
sql_passservice = pd.DataFrame([
    {
        'num': k,
        'name': f"{v.categoryName} {v.ritnummer} to {v.stops[-1].name}",
        'trainset': v.trainType if v.trainType
                    else TrainType.SLT if v.ritnummer == 9571
                    else TrainType.ICNG if v.categoryCode == CategoryCode.ECD
                    else None,
    }
    for k, v in train_timetables.items()
])

# %%
sql_stop = pd.DataFrame([
    {
        'passservice_num': passservice_id,
        'arrival': stop.arrives,
        'departure': stop.departs,
        'stations_uic': stop.station_uic,
    }
    for passservice_id, passservice in train_timetables.items()
    for stop in passservice.stops
])

# %% [markdown]
# ## Final cleanup/asserts

# %%
# delete rows missing both arrival/departure
sql_stop = sql_stop[~sql_stop[['arrival', 'departure']].isna().all(axis='columns')]

# %%
sql_stop.loc[sql_stop['arrival'] == sql_stop['departure'], 'departure'] += timedelta(seconds=30)
sql_stop.loc[sql_stop['arrival'] == sql_stop['departure']]
# Out:
# Empty DataFrame
# Columns: [passservice_num, arrival, departure, stations_uic]
# Index: []

# %%
# double-check, in sql_stop, that only first and last stops are missing arrival/departure
stops_sorted_groups = sql_stop.sort_values('arrival', na_position='first').groupby('passservice_num')
heads_departures = stops_sorted_groups.apply(lambda group: group['departure'].iloc[:-1])
tails_arrivals = stops_sorted_groups.apply(lambda group: group['arrival'].iloc[1:])
assert(heads_departures.notna().all().all())
assert(tails_arrivals.notna().all().all())

# %%
# fill first arrival, last departure with midnight the day before/after
first_arrival_update = sql_stop[['passservice_num', 'arrival']]
first_arrival_update = first_arrival_update.sort_values('arrival', na_position='first')
first_arrival_update['arrival'] = first_arrival_update['arrival'].dt.floor('D')
first_arrival_update['arrival'] = first_arrival_update.groupby('passservice_num')['arrival'].bfill(limit=1)
first_arrival_update = first_arrival_update.groupby('passservice_num').nth(0)
sql_stop['arrival'] = first_arrival_update['arrival'].reindex_like(sql_stop).where(pd.notna, sql_stop['arrival'])

last_departure_update = sql_stop[['passservice_num', 'arrival', 'departure']]
last_departure_update = last_departure_update.sort_values('arrival', na_position='first')
last_departure_update['departure'] = last_departure_update['departure'].dt.ceil('D')
last_departure_update['departure'] = last_departure_update.groupby('passservice_num')['departure'].ffill(limit=1)
last_departure_update = last_departure_update.groupby('passservice_num').nth(-1)
sql_stop['departure'] = last_departure_update['departure'].reindex_like(sql_stop).where(pd.notna, sql_stop['departure'])

# %%
# double-check table keys
assert (set(sql_passservice['trainset']) == set(sql_trainsetamenities['trainset']))
assert (set(sql_stop['stations_uic']) < set(sql_stations['uic']))
assert (set(sql_stop['passservice_num']) == set(sql_passservice['num']))

# %%
# also check which columns of any tables are nullable
assert (sql_stop.notna().all().all())
assert (sql_stations.notna().all().all())
assert (sql_passservice.notna().all().all())
assert (sql_trainsetamenities.notna().all().all())
# print('sql_stop', sql_stop.notna().all(axis='index'))
# print('sql_stations', sql_stations.notna().all(axis='index'))
# print('sql_passservice', sql_passservice.notna().all(axis='index'))
# print('sql_trainsetamenities', sql_trainsetamenities.notna().all(axis='index'))

# %% [markdown]
# ## Export

# %%
# export with .to_csv()
sql_stations.to_csv('./ns_results/stations.csv')
sql_trainsetamenities.to_csv('./ns_results/trainsetamenities.csv')
sql_passservice.to_csv('./ns_results/passservice.csv')
sql_stop.to_csv('./ns_results/stop.csv')

# %% [markdown]
# # UNUSED BELOW

# %% [markdown]
# ## Get train stock

# %%
# TREIN '/v1/trein' https://apiportal.ns.nl/api-details#api=virtual-train-API&operation=getTrainInformation
# TREINRIT '/v1/trein/{ritnummer}' https://apiportal.ns.nl/api-details#api=virtual-train-API&operation=getTrainInformationForRitnummer
# STATION VAN TREINRIT '/v1/trein/{ritnummer}/{stationscode}' https://apiportal.ns.nl/api-details#api=virtual-train-API&operation=getTrainInformationForRitnummerAndStationCode

# (Below are available from the three APIs above, but not all are applicable without specifying Rit and/or Station.)
# (Één MaterieelDeel bestaat uit meerdere Bakken.)

# TreinInformatie.ritnummer (int)
# TreinInformatie.type (string)
# TreinInformatie.geplandeMaterieeldelen[].materieelType (string)
# TreinInformatie.geplandeMaterieeldelen[].materieelnummer (int)
# TreinInformatie.geplandeMaterieeldelen[].type (string)
# TreinInformatie.geplandeMaterieeldelen[].faciliteiten (string[])

# %%
trein_pkl = Path('./ns_results/raw/trein_info.pkl')
if not trein_pkl.exists():
    response = requests.get(NSAPI_URLS['VIRTUAL_TRAIN'] + '/v1' + '/trein', headers=NS_GET_HEADER,
        params=nsapi.virtual_train.ApiV1TreinGetParameters(
            ids=train_id,
            # dateTime=(datetime.today() + timedelta(days=1)).isoformat().__str__(),
            all=True,
        )
    )
    print('Response:', response.json())
    obj = nsapi.virtual_train.TreinInformatie(**response.json())
    with open(trein_pkl, 'x+b') as file:
        pickle.dump(obj, file, protocol=-1)
else:
    with open(trein_pkl, 'rb') as file:
        obj = pickle.load(file)

# %%
# do we want to do /trein/ritnummer?
# trein_rit_pkl = Path('./ns_results/raw/trein_met_ritnummer_info.pkl')
# if not trein_rit_pkl.exists():
#     response = requests.get(NSAPI_URLS['VIRTUAL_TRAIN'] + '/v1' + f'/trein/{ritnummer}', headers=NS_GET_HEADER,
#         params=nsapi.virtual_train.ApiV1TreinRitnummerGetParameters(
#             # countryCodes=['NL'],
#             # limit=None # irrelevant when not providing str `q`
#         )
#     )
#     obj = nsapi.virtual_train.TreinInformatie(**response.json())
#     with open(trein_rit_pkl, 'x+b') as file:
#         pickle.dump(obj, file, protocol=-1)
# else:
#     with open(trein_rit_pkl, 'rb') as file:
#         obj = pickle.load(file)

# %%
# do we want to do /trein/ritnummer/stationscode?
# trein_rit_stations_pkl = Path('./ns_results/raw/trein_met_ritnummer_en_stationscode_info.pkl')
# if not trein_rit_stations_pkl.exists():
#     response = requests.get(NSAPI_URLS['VIRTUAL_TRAIN'] + '/v1' + f'/trein/{ritnummer}/{stationscode}', headers=NS_GET_HEADER,
#         params=nsapi.virtual_train.ApiV1TreinRitnummerStationscodeGetParameters(
#             # countryCodes=['NL'],
#             # limit=None # irrelevant when not providing str `q`
#         )
#     )
#     obj = nsapi.virtual_train.TreinInformatie(**response.json())
#     with open(trein_rit_stations_pkl, 'x+b') as file:
#         pickle.dump(obj, file, protocol=-1)
# else:
#     with open(trein_rit_stations_pkl, 'rb') as file:
#         obj = pickle.load(file)

# %% [markdown]
# ## Other data

# %%
# ARRIVALS 'https://gateway.apiportal.ns.nl/timetable-api/v2/arrivals' https://apiportal.ns.nl/api-details#api=reisinformatie-api&operation=getArrivals&definition=Arrival
# DEPARTURES 'https://gateway.apiportal.ns.nl/timetable-api/v2/departures' https://apiportal.ns.nl/api-details#api=reisinformatie-api&operation=getDepartures
# Arrivals[].plannedTimeZoneOffset
# Arrivals[].plannedDateTime
# Arrivals[].name
# Arrivals[].trainCategory
#   Arrivals[].product.displayName
#   Arrivals[].product.shortCategoryName
# Arrivals[].product.number (string)

# %%
arrivals_pkl = Path('./ns_results/raw/arrivals.pkl')
if not arrivals_pkl.exists():
    response = requests.get('https://gateway.apiportal.ns.nl/timetable-api' + '/v2' + '/arrivals', headers=NS_GET_HEADER,
        params=nsapi.reisinformatie.ApiV2ArrivalsGetParameters(
            # uicCode=station_uic_code
            maxJourneys=100 # default 40
        )
    )
    obj = nsapi.reisinformatie.RepresentationResponseArrivalsPayload(**response.json())
    with open(arrivals_pkl, 'x+b') as file:
        pickle.dump(obj, file, protocol=-1)
else:
    with open(arrivals_pkl, 'rb') as file:
        obj = pickle.load(file)

# %%
departures_pkl = Path('./ns_results/raw/departures.pkl')
if not departures_pkl.exists():
    response = requests.get('https://gateway.apiportal.ns.nl/timetable-api' + '/v2' + '/departures', headers=NS_GET_HEADER,
        params=nsapi.reisinformatie.ApiV2DeparturesGetParameters(
            # uicCode=station_uic_code
            maxJourneys=100, # default 40
        )
    )
    obj = nsapi.reisinformatie.RepresentationResponseDeparturesPayload(**response.json())
    with open(departures_pkl, 'x+b') as file:
        pickle.dump(obj, file, protocol=-1)
else:
    with open(departures_pkl, 'rb') as file:
        obj = pickle.load(file)
